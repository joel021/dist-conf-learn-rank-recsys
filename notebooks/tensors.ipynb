# %%
import torch

# %%
batch_size = 12

emb_dim = 5

a = torch.randn((batch_size, emb_dim))
b = torch.randn((batch_size, emb_dim))

# %%
(a*b).sum(dim=1)
# Out:
# tensor([-5.3612,  0.0737,  4.2718,  0.9692, -2.5388, -0.9270, -1.1570,  0.8904,
#         -1.1384,  0.0260,  0.7822,  2.6780])
