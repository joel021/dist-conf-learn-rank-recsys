# %%
import torch
import torch.nn as nn
import math

# %%
n_users = 1000000
n_items = 1000000
emb_size = 64

batch_size = 64

E_u = torch.randn(n_users, emb_size)
E_i = torch.randn(n_items, emb_size)

bn1 = nn.LayerNorm(emb_size)

# %%
id_u = torch.randn(batch_size, )
id_i = [2,1,0]

# %%
prod_matrix = torch.matmul(E_u[id_u], E_u.T)# Shape: (batch_size, n_entities)
prod_matrix = prod_matrix / math.sqrt(emb_size)
r_matrix = prod_matrix @ E_u #retrieval matrix

# %%
E_u.max()
# Out:
# tensor(5.6959)

# %%
prod_matrix.max(dim=1)
# Out:
# torch.return_types.max(
# values=tensor([9.2190, 9.6162, 5.4777]),
# indices=tensor([0, 1, 2]))

# %%
torch.sigmoid(torch.tensor(-10))
# Out:
# tensor(4.5398e-05)
